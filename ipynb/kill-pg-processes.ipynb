# %%
import psycopg2 as pg2
import pandas as pd

con = pg2.connect(host='this_postgres',
                  user='postgres',
                  password='password',
                  database='postgres')
con.autocommit = True
cur = con.cursor()

def select(sql):
    return pd.read_sql(sql,con)

# %% [markdown]
# Check running processes

# %%
sql = '''
SELECT pid , query, *
FROM pg_stat_activity pgsa
WHERE pid <> pg_backend_pid()
'''

# %%
df = select(sql)

# %%
df
# Out:
#    pid                        query    datid   datname  pid  usesysid  \
# 0   54                                   NaN      None   54       NaN
# 1   56                                   NaN      None   56      10.0
# 2   61                       COMMIT  13075.0  postgres   61      10.0
# 3   63  select * from hello_table t  13075.0  postgres   63      10.0
# 4   52                                   NaN      None   52       NaN
# 5   51                                   NaN      None   51       NaN
# 6   53                                   NaN      None   53       NaN
#
#     usename application_name client_addr client_hostname  ...  xact_start  \
# 0      None                         None            None  ...        None
# 1  postgres                         None            None  ...        None
# 2  postgres                   172.18.0.3            None  ...        None
# 3  postgres                   172.18.0.3            None  ...        None
# 4      None                         None            None  ...        None
# 5      None                         None            None  ...        None
# 6      None                         None            None  ...        None
#
#                        query_start                     state_change  \
# 0                              NaT                              NaT
# 1                              NaT                              NaT
# 2 2021-05-06 20:44:42.033527+00:00 2021-05-06 20:44:42.035121+00:00
# 3 2021-05-06 20:44:42.238753+00:00 2021-05-06 20:44:42.239197+00:00
# 4                              NaT                              NaT
# 5                              NaT                              NaT
# 6                              NaT                              NaT
#
#   wait_event_type           wait_event state backend_xid backend_xmin  \
# 0        Activity       AutoVacuumMain  None        None         None
# 1        Activity  LogicalLauncherMain  None        None         None
# 2          Client           ClientRead  idle        None         None
# 3          Client           ClientRead  idle        None         None
# 4        Activity         BgWriterMain  None        None         None
# 5        Activity     CheckpointerMain  None        None         None
# 6        Activity        WalWriterMain  None        None         None
#
#                          query         backend_type
# 0                               autovacuum launcher
# 1                                 background worker
# 2                       COMMIT       client backend
# 3  select * from hello_table t       client backend
# 4                                 background writer
# 5                                      checkpointer
# 6                                         walwriter
#
# [7 rows x 22 columns]

# %% [markdown]
# Kill all

# %%
sql = '''
SELECT 
    pg_terminate_backend(pid) 
FROM 
    pg_stat_activity 
WHERE 
    -- don't kill my own connection!
    pid <> pg_backend_pid()

'''

# %%
cur.execute(sql)

# %%
df
# Out:
#    pid                        query    datid   datname  pid  usesysid  \
# 0   54                                   NaN      None   54       NaN
# 1   56                                   NaN      None   56      10.0
# 2   61                       COMMIT  13075.0  postgres   61      10.0
# 3   63  select * from hello_table t  13075.0  postgres   63      10.0
# 4   52                                   NaN      None   52       NaN
# 5   51                                   NaN      None   51       NaN
# 6   53                                   NaN      None   53       NaN
#
#     usename application_name client_addr client_hostname  ...  xact_start  \
# 0      None                         None            None  ...        None
# 1  postgres                         None            None  ...        None
# 2  postgres                   172.18.0.3            None  ...        None
# 3  postgres                   172.18.0.3            None  ...        None
# 4      None                         None            None  ...        None
# 5      None                         None            None  ...        None
# 6      None                         None            None  ...        None
#
#                        query_start                     state_change  \
# 0                              NaT                              NaT
# 1                              NaT                              NaT
# 2 2021-05-06 20:44:42.033527+00:00 2021-05-06 20:44:42.035121+00:00
# 3 2021-05-06 20:44:42.238753+00:00 2021-05-06 20:44:42.239197+00:00
# 4                              NaT                              NaT
# 5                              NaT                              NaT
# 6                              NaT                              NaT
#
#   wait_event_type           wait_event state backend_xid backend_xmin  \
# 0        Activity       AutoVacuumMain  None        None         None
# 1        Activity  LogicalLauncherMain  None        None         None
# 2          Client           ClientRead  idle        None         None
# 3          Client           ClientRead  idle        None         None
# 4        Activity         BgWriterMain  None        None         None
# 5        Activity     CheckpointerMain  None        None         None
# 6        Activity        WalWriterMain  None        None         None
#
#                          query         backend_type
# 0                               autovacuum launcher
# 1                                 background worker
# 2                       COMMIT       client backend
# 3  select * from hello_table t       client backend
# 4                                 background writer
# 5                                      checkpointer
# 6                                         walwriter
#
# [7 rows x 22 columns]
